# %%
# %matplotlib inline    
import matplotlib as mplt
from matplotlib import cm
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

import matplotlib
from matplotlib.ticker import FuncFormatter
import matplotlib.pyplot as plt
# matplotlib.style.use('ggplot')

from utils_libs import *

import statsmodels as sm
from statsmodels.tsa.stattools import acf  
from statsmodels.tsa.stattools import pacf
from statsmodels.tsa.api import VAR, DynamicVAR

from statsmodels.stats import diagnostic
# Out:
# /home/guo/.local/lib/python2.7/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
# ---- Load pre-processed training and testing data ----

file_postfix = "v_minu_mix"

xtrain = np.load("../dataset/bitcoin/training_data/xtrain_"+file_postfix+".dat")
xtest  = np.load("../dataset/bitcoin/training_data/xtest_" +file_postfix+".dat")
ytrain = np.load("../dataset/bitcoin/training_data/ytrain_"+file_postfix+".dat")
ytest  = np.load("../dataset/bitcoin/training_data/ytest_" +file_postfix+".dat")

print np.shape(xtrain), np.shape(ytrain), np.shape(xtest), np.shape(ytest)

print len(gate_tr), len(gate_ts)

# %%
def plot_prediction_truth(file_add, title, num):
    test_df = pd.read_csv(file_add, sep=',', names = ['vol','ob'])
    
    fig, ax = plt.subplots()
    fig.set_size_inches( 18,7 )
    
    ax.plot(test_df.iloc[:num], lw=2)
    ax.legend( ['Prediction','True values'], loc=0)
    ax.set_ylim(-.1, 1.5)
    ax.legend()
    
    plt.title(title)

# %%
num_toshow = 500
plot_prediction_truth('res/pytest_bayes.txt', 'Bayes regression', num_toshow)
plot_prediction_truth('res/pytest_enet.txt', 'Elastic net', num_toshow)
plot_prediction_truth('res/pytest_rf.txt', 'Random forest', num_toshow)
plot_prediction_truth('res/pytest_gbt.txt', 'Gradient boostet tree', num_toshow)

plot_prediction_truth('res/pytest.txt', 'Mixture linear', num_toshow)

# %%
#---- lk ----

test_df = pd.read_csv('res/pytest.txt',    sep=',', names = ['pred', 'true'])
gate_tr = pd.read_csv('res/gate_train.txt',sep=',', names = ['vol','ob'])
gate_ts = pd.read_csv('res/gate_test.txt', sep=',', names = ['vol','ob'])
print test_df.shape, gate_tr.shape, gate_ts.shape

plot_horizon = 20

plot_prediction_truth('res/pytest.txt', 'Mixture linear', plot_horizon)
tmp_gate =  np.asarray(gate_ts.iloc[:plot_horizon])

# for i in range(3, len(tmp_gate)-3):
#      tmp_gate[i][0] = mean([tmp_gate[j][0] for j in range(i+1, i+2)])

X = range(len(tmp_gate))
Y =  [1.0 for i in tmp_gate ]
Y1 = [i[0] for i in tmp_gate]
Y2 = [0.0 for i in tmp_gate]

fig, ax = plt.subplots()
fig.set_size_inches( 18,7 )

ax.plot(Y, label = 'Order book', color='k', alpha=.5)
ax.plot(Y1,label = 'Volatility', color = 'y')
ax.plot(Y2,)
plt.fill_between(X, Y, Y1, color='k',alpha=.5)
plt.fill_between(X, Y1,Y2, color='y',alpha=.5)

ax.legend(loc=0)
# Out:
# (2125, 2) (8500, 2) (2125, 2)

# %%
#---- log lk ----

test_df = pd.read_csv('res/pytest.txt',    sep=',', names = ['pred', 'true'])
gate_tr = pd.read_csv('res/gate_train.txt',sep=',', names = ['vol','ob'])
gate_ts = pd.read_csv('res/gate_test.txt', sep=',', names = ['vol','ob'])
print test_df.shape, gate_tr.shape, gate_ts.shape

plot_prediction_truth('res/pytest.txt', 'Mixture linear', 500)

tmp_gate =  np.asarray(gate_ts.iloc[:500])

# for i in range(3, len(tmp_gate)-3):
#      tmp_gate[i][0] = mean([tmp_gate[j][0] for j in range(i+1, i+2)])

X = range(len(tmp_gate))
Y =  [1.0 for i in tmp_gate ]
Y1 = [i[0] for i in tmp_gate]
Y2 = [0.0 for i in tmp_gate]

fig, ax = plt.subplots()
fig.set_size_inches( 18,7 )

ax.plot(Y, label = 'Order book', color='k', alpha=.5)
ax.plot(Y1,label = 'Volatility', color = 'y')
ax.plot(Y2,)
plt.fill_between(X, Y, Y1, color='k',alpha=.5)
plt.fill_between(X, Y1,Y2, color='y',alpha=.5)

ax.legend(loc=0)
# Out:
# (2125, 2) (8500, 2) (2125, 2)

# %%
#---- sq ----

test_df = pd.read_csv('res/pytest.txt',    sep=',', names = ['pred', 'true'])
gate_tr = pd.read_csv('res/gate_train.txt',sep=',', names = ['vol','ob'])
gate_ts = pd.read_csv('res/gate_test.txt', sep=',', names = ['vol','ob'])
print test_df.shape, gate_tr.shape, gate_ts.shape


plot_prediction_truth('res/pytest.txt', 'Mixture linear', 500)

tmp_gate =  np.asarray(gate_ts.iloc[:500])

#for i in range(3, len(tmp_gate)-3):
 #    tmp_gate[i][0] = mean([tmp_gate[j][0] for j in range(i-1, i+1)])

X = range(len(tmp_gate))
Y =  [1.0 for i in tmp_gate ]
Y1 = [i[0] for i in tmp_gate]
Y2 = [0.0 for i in tmp_gate]

fig, ax = plt.subplots()
fig.set_size_inches( 18,7 )

ax.plot(Y, label = 'Order book', color='k', alpha=.5)
ax.plot(Y1,label = 'Volatility', color = 'y')
ax.plot(Y2,)
plt.fill_between(X, Y, Y1, color='k',alpha=.5)
plt.fill_between(X, Y1,Y2, color='y',alpha=.5)

ax.legend(loc=0)
# Out:
# (2125, 2) (8500, 2) (2125, 2)
# /usr/lib/python2.7/dist-packages/matplotlib/axes/_axes.py:519: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %%
#---- log sq ----

test_df = pd.read_csv('res/pytest.txt',    sep=',', names = ['pred', 'true'])
gate_tr = pd.read_csv('res/gate_train.txt',sep=',', names = ['vol','ob'])
gate_ts = pd.read_csv('res/gate_test.txt', sep=',', names = ['vol','ob'])
print test_df.shape, gate_tr.shape, gate_ts.shape

plot_horizon = 20
plot_prediction_truth('res/pytest.txt', 'Mixture linear', plot_horizon)
tmp_gate =  np.asarray(gate_ts.iloc[:plot_horizon])

# for i in range(3, len(tmp_gate)-3):
#      tmp_gate[i][0] = mean([tmp_gate[j][0] for j in range(i-1, i+1)])

X = range(len(tmp_gate))
Y =  [1.0 for i in tmp_gate ]
Y1 = [i[0] for i in tmp_gate]
Y2 = [0.0 for i in tmp_gate]

fig, ax = plt.subplots()
fig.set_size_inches( 18,7 )

ax.plot(Y, label = 'Order book', color='k', alpha=.5)
ax.plot(Y1,label = 'Volatility', color = 'y')
ax.plot(Y2,)
plt.fill_between(X, Y, Y1, color='k',alpha=.5)
plt.fill_between(X, Y1,Y2, color='y',alpha=.5)

ax.legend(loc=0)
# Out:
# (2125, 2) (8500, 2) (2125, 2)

# %%
#---- lognorm ----

test_df = pd.read_csv('res/pytest.txt',    sep=',', names = ['pred', 'true'])
gate_tr = pd.read_csv('res/gate_train.txt',sep=',', names = ['vol','ob'])
gate_ts = pd.read_csv('res/gate_test.txt', sep=',', names = ['vol','ob'])
print test_df.shape, gate_tr.shape, gate_ts.shape


plot_prediction_truth('res/pytest.txt', 'Mixture linear', 500)

tmp_gate =  np.asarray(gate_ts.iloc[:500])

# for i in range(3, len(tmp_gate)-3):
#      tmp_gate[i][0] = mean([tmp_gate[j][0] for j in range(i+1, i+2)])

X = range(len(tmp_gate))
Y =  [1.0 for i in tmp_gate ]
Y1 = [i[0] for i in tmp_gate]
Y2 = [0.0 for i in tmp_gate]

fig, ax = plt.subplots()
fig.set_size_inches( 18,7 )

ax.plot(Y, label = 'Order book', color='k', alpha=.5)
ax.plot(Y1,label = 'Volatility', color = 'y')
ax.plot(Y2,)
plt.fill_between(X, Y, Y1, color='k',alpha=.5)
plt.fill_between(X, Y1,Y2, color='y',alpha=.5)

ax.legend(loc=0)


# TO DO: plot component
# Out:
# (2125, 2) (8500, 2) (2125, 2)

# %%
# To do: conditiaonl error distribution
# distibution of mixture weights

def vol_condition_on_ob( gate, y, lower, upper ):
   
    tmpv = []
    tmpob= []
    gate = np.asarray(gate)
    for i in range(1,len(gate)):
        tmp_v =  gate[i][0]
        tmp_ob = gate[i][1]
        
        if y[i] >=lower and y[i]<=upper:
            tmpv.append(tmp_v)
            tmpob.append(tmp_ob)
    
    print lower, upper, " : ", len(tmpv), mean(tmpv), mean(tmpob),' p-value: ', sp.stats.ttest_ind(tmpv,tmpob)[1]

print max(ytrain), min(ytrain)
print max(ytest), min(ytest)

print 'Training:'
for i in range(1,50):
    vol_condition_on_ob( gate_tr, ytrain, 0.1*i, 0.1*(i+1) )
    
    
print '\nTesting:'
for i in range(1,30):
    vol_condition_on_ob( gate_ts, ytest, 0.05*i, 0.05*(i+1) )
# Out:
# 4.43378288192 0.0
# 1.39532489949 0.0
# Training:
# 0.1 0.2  :  1834 0.922268664833 0.0777313354515  p-value:  0.0
# 0.2 0.3  :  578 0.791438124359 0.208561876329  p-value:  9.09040781994e-168
# 0.3 0.4  :  254 0.614007972744 0.385992027612  p-value:  6.76585427659e-11
# 0.4 0.5  :  120 0.52749757759 0.472502424169  p-value:  0.313785099662
# 0.5 0.6  :  53 0.361613662853 0.638386335373  p-value:  0.000544678999159
# 0.6 0.7  :  37 0.350732866529 0.649267131286  p-value:  0.000953605377653
# 0.7 0.8  :  34 0.234907645258 0.765092336347  p-value:  1.95418493465e-08
# 0.8 0.9  :  20 0.290811175361 0.709188834205  p-value:  0.000622954373106
# 0.9 1.0  :  17 0.290549347765 0.709450639353  p-value:  0.00202138108601
# 1.0 1.1  :  15 0.294650203194 0.705349786828  p-value:  0.0060205128542
# 1.1 1.2  :  10 0.089144184801 0.910855807364  p-value:  5.31956836318e-07
# 1.2 1.3  :  3 0.000771529976419 0.99922845761  p-value:  3.61617954759e-12
# 1.3 1.4  :  6 0.045150412062 0.954849590858  p-value:  4.60563817438e-08
# 1.4 1.5  :  7 0.154344155436 0.845655875547  p-value:  0.00148020088107
# 0.7 0.75  :  1 0.998251259327 0.00174874940421  p-value:  nan
# 0.75 0.8  :  0 nan nan  p-value:  nan
# 0.8 0.85  :  0 nan nan  p-value:  nan
# 0.85 0.9  :  1 0.00794858671725 0.992051362991  p-value:  nan
# 0.9 0.95  :  0 nan nan  p-value:  nan
# 0.95 1.0  :  0 nan nan  p-value:  nan
# 1.0 1.05  :  1 0.998487830162 0.00151217647363  p-value:  nan
# 1.05 1.1  :  0 nan nan  p-value:  nan
# 1.1 1.15  :  0 nan nan  p-value:  nan
# 1.15 1.2  :  0 nan nan  p-value:  nan
# 1.2 1.25  :  0 nan nan  p-value:  nan
# 1.25 1.3  :  0 nan nan  p-value:  nan
# 1.3 1.35  :  0 nan nan  p-value:  nan
# 1.35 1.4  :  1 0.272950381041 0.727049589157  p-value:  nan
# 1.4 1.45  :  0 nan nan  p-value:  nan
# 1.45 1.5  :  0 nan nan  p-value:  nan

# %%
def vol_condition_on_ob( data, lower, upper ):
    
    tmpy = []
    
    gate = np.asarray(data)
    for i in range(1,len(gate)):
        tmp_v =  gate[i][0]
        tmp_ob = gate[i][1]
        
        if tmp_ob>=lower and tmp_ob<=upper:
            tmpy.append(ytest[i])
    
    print len(tmpy)
    return tmpy
    

for i in range(1,10):
    tmpy = vol_condition_on_ob( gate_ts, 0.1*i, 0.1*(i+1) )
    fig, ax = plt.subplots()
    ax.hist(tmpy, histtype='bar', bins=30,  label='Density of Volatility Weights')
#     ax.set_xlim(0,0.6)
# Out:
# 1343
# 386
# 98
# 22
# 6
# 7
# 2
# 1
# 3

# %%
fig, ax = plt.subplots()
ax.hist(gate_tr['vol'], histtype='bar', bins=30, normed= 1, label='Density of Volatility Weights')
ax.legend()
# ax.set_ylim(0,10)
ax.set_xlim(0,1.0)
plt.title("Training data")
# ax.title("Training data")

fig, ax = plt.subplots()
ax.hist(gate_tr['ob'], histtype='bar',  bins=30,normed= 1, label='Density of Order-book Weights')
ax.legend()
# ax.set_ylim(0,10)
ax.set_xlim(0,1.0)
plt.title('Training data')

# %%
fig, ax = plt.subplots()
ax.hist(gate_ts['vol'], histtype='bar', bins=30, normed= 1, label='Density of Volatility Weights')
ax.legend()
plt.title("Testing data")
# ax.set_ylim(0,600)
ax.set_xlim(0,1.0)

fig, ax = plt.subplots()
ax.hist(gate_ts['ob'], histtype='bar',  bins=30, normed= 1, label='Density of Order-book Weights')
ax.legend(loc=0)
# ax.set_ylim(0,600)
ax.set_xlim(0,1.0)
plt.title('Testing data')

# %%
resi = test_df['true']-test_df['pred']

fig, ax = plt.subplots()
fig.set_size_inches( 18,7 )
ax.hist(resi, histtype='bar', bins=30, normed= 1)
ax.legend()
# ax.set_ylim(0,10)
# ax.set_xlim(0,1.0)
plt.title("Training data")
# ax.title("Training data")

fig, ax = plt.subplots()
fig.set_size_inches( 18,7 )
ax.plot(resi, lw=2)
# ax.legend( ['Prediction','True values'], loc=0)

bitcoin order book
# Ljung–Box test on residuals to test no auto-correlation
print sm.stats.diagnostic.acorr_ljungbox(resi, lags=None, boxpierce=False)[1]

# Normality test
print sp.stats.mstats.normaltest(resi)

sp.stats.kstest(resi, 'norm')
